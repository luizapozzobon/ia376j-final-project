# %% [markdown]
# # Projeto Final -  Treino DocVQA
#
# Nesse notebook realizei o treino com o dataset DocVQA com o checkpoint do pré-treino de OCR do dataset SQuAD 2.0.
#
# ### Sobre as imagens
#
# Algumas características do dataset sintético gerado:
# - Tamanho de imagem: 576x768
# - Tamanho da sequência de saída: até 20 tokens
#
#
# ### Sobre o treino
#
# - Uso do t5-base (d_model = 768).
# - Geração de patches da imagem e a seguir reshape para `batch x 384 x 768`.
# - Concatenação da pergunta junto aos embeddings de texto. As perguntas tem shape: `batch x 20 x 768`.
# - Sequence length das perguntas: 20
# - Otimizador: Adafactor
# - Batch size: 2
# - Grad accum: 8
# - Limit val batches: 0.2

# %% [markdown]
# ## Importações e downloads

# %%
# !nvidia-smi
# Out:
# Wed Jan  6 23:23:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.87.01    Driver Version: 418.87.01    CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    29W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install ftfy datasets pytorch-lightning transformers==3.5.1 --quiet

# %%
# !pip install neptune-client neptune-contrib[all] neptune-notebooks --quiet

# %%
neptune_params = {
    'api_key': 'eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vdWkubmVwdHVuZS5haSIsImFwaV91cmwiOiJodHRwczovL3VpLm5lcHR1bmUuYWkiLCJhcGlfa2V5IjoiZDYyNzIxNTYtMjFkMi00ODk3LTk3ZjQtOWRjYzQ4NjAxNjIzIn0=',
    'project_name': 'lupozz/ia376-doc-vqa'
}

# %%
import os
import glob
import json
import random
import numpy as np
from PIL import Image
from imageio import imread
from collections import OrderedDict
from tqdm.notebook import tqdm
from itertools import product
from functools import partial
from copy import copy
from datetime import datetime
from pathlib import Path

from matplotlib import pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torch.utils.data import Dataset

from fairseq.optim.adafactor import Adafactor

from pytorch_lightning.loggers.neptune import NeptuneLogger

from transformers import T5Tokenizer
from transformers import T5ForConditionalGeneration

import pytorch_lightning as pl
import transformers

print(f"""PyTorch Version: {torch.__version__}
          \rLightning Version: {pl.__version__}
          \rTransformers Version: {transformers.__version__}""")

model_name = 't5-base'
tokenizer = T5Tokenizer.from_pretrained(model_name)
# Out:
# PyTorch Version: 1.4.0
# Lightning Version: 1.0.6
# Transformers Version: 3.5.1

# %%
if torch.cuda.is_available(): 
    dev = "cuda:0"
else: 
    dev = "cpu" 
print(dev)
device = torch.device(dev)
# Out:
# cuda:0

# %%
# !gsutil -m cp -n gs://neuralresearcher_data/unicamp/ia376j_2020s2/aula7/arial.ttf .
# Out:
# Skipping existing item: file://./arial.ttf

# %% [markdown]
# ## Funções auxiliares

# %% [markdown]
# ### Métricas

# %%
# Métricas feitas pelo professor de um notebook de outra aula

import collections

def normalize_answer(s):
    """Lower text and remove extra whitespace."""

    def white_space_fix(text):
        return ' '.join(text.split())

    def lower(text):
        return text.lower()

    return white_space_fix(lower(s))

def get_tokens(s):
    if not s: return []
    return normalize_answer(s).split()

def compute_exact(a_gold, a_pred):
    return int(normalize_answer(a_gold) == normalize_answer(a_pred))

def compute_f1(a_gold, a_pred):
    gold_toks = get_tokens(a_gold)
    pred_toks = get_tokens(a_pred)
    common = collections.Counter(gold_toks) & collections.Counter(pred_toks)
    num_same = sum(common.values())
    if len(gold_toks) == 0 or len(pred_toks) == 0:
        # If either is no-answer, then F1 is 1 if they agree, 0 otherwise
        return int(gold_toks == pred_toks)
    if num_same == 0:
        return 0
    precision = 1.0 * num_same / len(pred_toks)
    recall = 1.0 * num_same / len(gold_toks)
    f1 = (2 * precision * recall) / (precision + recall)
    return f1

# %% [markdown]
# ## Dataset

# %%
class DocVQA(Dataset):
    """Dataset DocVQA.
    
    Carregamento das imagens e das perguntas relacionadas a ela.
    Faço um dataset "flat", onde o tamanho é dado pelo número de perguntas.
    As imagens aparecem k vezes, sendo k a quantia de perguntas por imagem.
    
    """
    def __init__(self, images_path, qa_path, transform=None):
        self.transform = transform
        self.images_paths = self._get_images_paths(images_path)

        qa_json = json.load(open(str(qa_path)))
        self.qa = self.organize_qa(qa_json['data'])

    def __getitem__(self, index, rescale=False):
        instance = self.qa[index]
        
        image = self._load_image(instance['image'])
        ocr = self._load_ocr(instance['image'])
        question = instance['question']
        answer = instance['answer']

        original_shape = np.array(image).shape
        
        if self.transform is not None:
            image = self.transform(image)
            new_shape = image.shape

            if new_shape != original_shape and rescale:
                # Caso o shape tenha sido modificado, é necessário fazer o reshape das bboxes
                ocr['flattened_words'] = self.rescale_bboxes(
                    ocr['flattened_words'], 
                    original_shape, 
                    new_shape=new_shape)

        return image, ocr, question, answer

    def __len__(self):
        return len(self.qa)

    def _get_images_paths(self, path):
        """Construção de um dicionário com a imagem e seu caminho.
        
        Args:
            path (str): Caminho para a pasta de imagens.
            
        Return:
            (dict): Dicionário com nome da imagem como chave e seu caminho como valor.
        
        """
        paths = sorted(glob.glob(f'{path}/*.png'))
        return {p.split('/')[-1]: p for p in paths}

    def organize_qa(self, questions_list):
        """ Organização das perguntas, respostas e imagens correspondentes.
        
        Args:
            questions_list (list): Lista de perguntas das imagens. Entrada "data" do
            arquivo original do dataset.
        
        Return:
            flat_qa (list): Cada pergunta é uma instância. As imagens podem aparecer
            k vezes na época e as respostas são sorteadas.
        
        """
        images_names = list(self.images_paths.keys())
        qa = {img: [] for img in images_names}

        # Cada imagem tem um conjunto de perguntas e respostas.
        # Aqui faço o ajuste preliminar do dataset de question answering.
        for instance in questions_list:
            curr_image = instance['image'].replace('documents/', '')
            if 'answers' in instance:
                answers = instance['answers']
            else:
                answers = ['No answer.']
            question = instance['question']

            qa[curr_image].append({'question': question,
                                   'answers': answers})
            
        # Aqui, cada pergunta vira uma entrada do dataset, então
        # as imagens podem aparecer k vezes em uma mesma época, mas
        # com perguntas diferentes. As respostas são sorteadas.
        flat_qa = [{'image': key, 
                    'question': item['question'], 
                    'answer': np.random.choice(item['answers'])} 
                   for key, value in qa.items() for item in value]
        
        return flat_qa

    def _load_image(self, image_name):
        return Image.open(self.images_paths[image_name]).convert("RGB")

    def _load_ocr(self, image_name):
        """Carregamento do OCR de uma imagem do dataset.
        
        Args:
            image_name (str): Nome da imagem da qual queremos o OCR.
        
        Return:
            (dict): Dicionário com o OCR em texto corrido ('full_text') e
            uma lista com as palavras e suas bounding boxes ('flattened_words').

        """
        label_path = self.images_paths[image_name].replace('documents', 
                                                           'ocr_results').replace('.png', 
                                                                                  '.json')
        label = json.load(open(label_path, 'r'))

        words_by_line = [line['words'] for result in label['recognitionResults'] 
                         for line in result['lines']]
        flattened_words = [word for words in words_by_line for word in words]
        full_text = ' '.join([f['text'] for f in flattened_words])

        return {'flattened_words': flattened_words, 'full_text': full_text}

    def rescale_bboxes(self, label, original_shape, new_shape):
        """Resize de bounding boxes do OCR para o novo shape de uma imagem. 
        
        Args:
            label (list): OCR em formato de lista com palavra e bounding box.
            original_shape (tuple): Tamanho original da imagem que gerou o OCR.
            new_shape (tuple): Tamanho da imagem após resize.
        
        """
        words = []
        for word in label:
            bbox = np.array(word['boundingBox']) # bbox = [x1, y1, x2, y2, x3, y3, x4, y4]
            x = bbox[0::2] / original_shape[1] * new_shape[2]
            y = bbox[1::2] / original_shape[0] * new_shape[1]
            word['boundingBox'] = {'x': x.astype('int'), 'y': y.astype('int')}
            words.append(word)
        return words

    def show(self, index, figsize=(15, 10)):
        """Plot de uma amostra específica do dataset.
        
        """
        image, ocr, question, answer = self[index]

        if not isinstance(image, np.ndarray):
            image = image.numpy().transpose(1, 2, 0)

        plt.figure(figsize=figsize)
        plt.imshow(image)
        plt.show()

        print(f"""OCR: {ocr['full_text']}
                \rQuestion: {question}
                \rAnswer: {answer}""")

    def show_batch(self, size=1, figsize=(30, 30), with_bboxes=False):
        """Plot de amostras aleatórias do dataset.
        
        """
        samples = np.random.randint(0, high=self.__len__(), size=size)
        for i, sample in enumerate(samples):
            plt.figure(figsize=figsize)

            image, ocr, question, answer = self.__getitem__(sample, 
                                                            rescale=True)
            image = image.numpy().transpose(1, 2, 0)

            # Pra plotar com as bboxes
            if with_bboxes:
                for word in label:
                    x = list(word['boundingBox']['x'])
                    y = list(word['boundingBox']['y'])
                    x += [x[0]] # Pra fechar o retângulo
                    y += [y[0]]
                    plt.plot(x, y, color='red')
  
            plt.gca().invert_yaxis() # Os bounding boxes tem origem no topo esquerdo.
            
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])
            plt.show()

            print(f"""OCR: {ocr['full_text']}
                    \rQuestion: {question}
                    \rAnswer: {answer}""")

# %%
transform = transforms.Compose([
    transforms.Resize((768, 576)),
    transforms.ToTensor(),
    transforms.Lambda(lambda img: img * 2.0  - 1.0),
])

doc_vqa_path = Path('doc-vqa')

train_ds = DocVQA(doc_vqa_path / 'train' / 'documents', 
                  doc_vqa_path / 'train' / 'train_v1.0.json',
                  transform=transform)

val_ds = DocVQA(doc_vqa_path / 'val' / 'documents', 
                doc_vqa_path / 'val' / 'val_v1.0.json',
                transform=transform)

test_ds = DocVQA(doc_vqa_path / 'test' / 'documents', 
                 doc_vqa_path / 'test' / 'test_v1.0.json',
                 transform=transform)

# %%
image, ocr, question, answer = val_ds[123]

# %%
image.shape
# Out:
# torch.Size([3, 768, 576])

# %%
ocr # Aqui tem o OCR completo em 'full_text' e as bboxes em 'flattened_words'
# Out:
# {'flattened_words': [{'boundingBox': [2013,
#     88,
#     2116,
#     85,
#     2119,
#     116,
#     2014,
#     118],
#    'text': '52248'},
#   {'boundingBox': [2138, 84, 2214, 80, 2217, 111, 2141, 115], 'text': '7681'},
#   {'boundingBox': [1635, 144, 1695, 144, 1695, 182, 1635, 182], 'text': 'For'},
#   {'boundingBox': [1703, 144, 1804, 144, 1805, 182, 1703, 182],
#    'text': 'years,'},
#   {'boundingBox': [1812, 143, 2026, 141, 2026, 180, 1812, 182],
#    'text': 'anti-smokers'},
#   {'boundingBox': [2033, 141, 2115, 140, 2116, 179, 2034, 180],
#    'text': 'have'},
#   {'boundingBox': [2123, 140, 2207, 138, 2208, 178, 2123, 179],
#    'text': 'been'},
#   {'boundingBox': [1635, 182, 1737, 183, 1738, 219, 1635, 219],
#    'text': 'trying'},
#   {'boundingBox': [1745, 183, 1779, 184, 1780, 219, 1745, 219], 'text': 'to'},
#   {'boundingBox': [1786, 184, 1862, 184, 1863, 219, 1787, 219],
#    'text': 'take'},
#   {'boundingBox': [1869, 184, 2040, 183, 2041, 218, 1870, 219],
#    'text': 'advantage'},
#   {'boundingBox': [2047, 183, 2079, 182, 2081, 218, 2049, 218], 'text': 'of'},
#   {'boundingBox': [2086, 182, 2147, 181, 2149, 217, 2088, 218], 'text': 'you'},
#   {'boundingBox': [2154, 181, 2220, 180, 2223, 216, 2157, 217],
#    'text': 'just'},
#   {'boundingBox': [1633, 219, 1772, 222, 1773, 255, 1634, 252],
#    'text': 'because'},
#   {'boundingBox': [1778, 222, 1840, 222, 1841, 255, 1779, 255], 'text': 'you'},
#   {'boundingBox': [1851, 222, 1969, 220, 1968, 253, 1851, 255],
#    'text': 'smoke!'},
#   {'boundingBox': [900, 265, 923, 263, 926, 289, 903, 292],
#    'text': '.',
#    'confidence': 'Low'},
#   {'boundingBox': [929, 262, 961, 258, 964, 285, 932, 289], 'text': '..'},
#   {'boundingBox': [326, 377, 1325, 249, 1355, 437, 360, 568],
#    'text': 'SMOKERS!'},
#   {'boundingBox': [1638, 290, 1766, 292, 1766, 331, 1638, 331],
#    'text': "They've"},
#   {'boundingBox': [1774, 292, 1857, 293, 1857, 330, 1774, 331],
#    'text': 'been'},
#   {'boundingBox': [1865, 293, 1983, 292, 1982, 330, 1865, 330],
#    'text': 'raising'},
#   {'boundingBox': [1991, 292, 2071, 291, 2070, 329, 1990, 330],
#    'text': 'your'},
#   {'boundingBox': [2079, 291, 2229, 288, 2228, 328, 2078, 329],
#    'text': 'cigarette'},
#   {'boundingBox': [1637, 331, 1735, 331, 1735, 366, 1638, 367],
#    'text': 'taxes.'},
#   {'boundingBox': [1742, 331, 1994, 330, 1993, 365, 1742, 366],
#    'text': 'Discriminating'},
#   {'boundingBox': [2001, 330, 2122, 329, 2122, 364, 2001, 365],
#    'text': 'against'},
#   {'boundingBox': [2129, 329, 2191, 328, 2190, 364, 2129, 364], 'text': 'you'},
#   {'boundingBox': [2198, 328, 2233, 328, 2233, 363, 2197, 364], 'text': 'in'},
#   {'boundingBox': [1638, 367, 1693, 367, 1693, 404, 1637, 404], 'text': 'the'},
#   {'boundingBox': [1701, 367, 1883, 366, 1883, 403, 1700, 404],
#    'text': 'workplace.'},
#   {'boundingBox': [1890, 366, 2078, 365, 2078, 403, 1890, 403],
#    'text': 'Forbidding'},
#   {'boundingBox': [2085, 365, 2150, 365, 2150, 403, 2085, 403], 'text': 'you'},
#   {'boundingBox': [2157, 365, 2193, 365, 2193, 403, 2157, 403], 'text': 'to'},
#   {'boundingBox': [1639, 405, 1749, 404, 1750, 441, 1640, 443],
#    'text': 'smoke'},
#   {'boundingBox': [1756, 404, 1791, 404, 1791, 440, 1757, 441], 'text': 'in'},
#   {'boundingBox': [1798, 404, 1901, 403, 1901, 439, 1799, 440],
#    'text': 'public'},
#   {'boundingBox': [1908, 403, 2013, 402, 2014, 438, 1909, 439],
#    'text': 'places'},
#   {'boundingBox': [2021, 402, 2048, 402, 2048, 438, 2021, 438], 'text': '-'},
#   {'boundingBox': [2072, 402, 2151, 402, 2150, 438, 2072, 438],
#    'text': 'even'},
#   {'boundingBox': [2158, 402, 2192, 401, 2192, 438, 2158, 438], 'text': 'in'},
#   {'boundingBox': [1639, 446, 1719, 445, 1719, 480, 1639, 481],
#    'text': 'your'},
#   {'boundingBox': [1726, 445, 1794, 443, 1794, 479, 1726, 480], 'text': 'own'},
#   {'boundingBox': [1801, 443, 1906, 441, 1905, 477, 1801, 479],
#    'text': 'home!'},
#   {'boundingBox': [436, 622, 692, 590, 712, 735, 455, 752], 'text': 'Get'},
#   {'boundingBox': [718, 587, 1298, 509, 1319, 651, 737, 733],
#    'text': 'together'},
#   {'boundingBox': [1642, 512, 1769, 513, 1769, 553, 1642, 556],
#    'text': "They've"},
#   {'boundingBox': [1777, 513, 1861, 513, 1861, 551, 1777, 552],
#    'text': 'been'},
#   {'boundingBox': [1870, 513, 2002, 512, 2002, 551, 1869, 551],
#    'text': 'treating'},
#   {'boundingBox': [2011, 512, 2071, 511, 2071, 552, 2010, 551], 'text': 'you'},
#   {'boundingBox': [2080, 511, 2146, 510, 2145, 553, 2079, 552],
#    'text': 'like'},
#   {'boundingBox': [2155, 510, 2172, 509, 2171, 553, 2154, 553], 'text': 'a'},
#   {'boundingBox': [1641, 554, 1849, 551, 1850, 586, 1642, 589],
#    'text': 'second-class'},
#   {'boundingBox': [1856, 550, 1978, 549, 1979, 586, 1857, 586],
#    'text': 'citizen.'},
#   {'boundingBox': [1985, 549, 2045, 548, 2046, 586, 1986, 586], 'text': 'But'},
#   {'boundingBox': [2052, 548, 2077, 548, 2079, 586, 2053, 586], 'text': 'it'},
#   {'boundingBox': [2084, 548, 2160, 547, 2162, 587, 2086, 586],
#    'text': "isn't"},
#   {'boundingBox': [1642, 590, 1780, 592, 1779, 627, 1642, 624],
#    'text': 'working'},
#   {'boundingBox': [1786, 592, 1847, 592, 1846, 627, 1786, 627], 'text': 'any'},
#   {'boundingBox': [1854, 592, 1946, 592, 1945, 624, 1853, 627],
#    'text': 'more.'},
#   {'boundingBox': [1641, 661, 1717, 661, 1717, 700, 1641, 699], 'text': 'Now'},
#   {'boundingBox': [1729, 661, 1873, 661, 1873, 701, 1729, 700],
#    'text': 'smokers'},
#   {'boundingBox': [1881, 660, 1933, 660, 1934, 701, 1881, 701], 'text': 'are'},
#   {'boundingBox': [1941, 660, 2075, 658, 2075, 699, 1942, 701],
#    'text': 'fighting'},
#   {'boundingBox': [2082, 657, 2173, 655, 2174, 698, 2083, 699],
#    'text': 'back.'},
#   {'boundingBox': [561, 764, 694, 747, 709, 879, 575, 891], 'text': 'to'},
#   {'boundingBox': [728, 742, 1218, 677, 1236, 794, 742, 876],
#    'text': 'protect'},
#   {'boundingBox': [1646, 696, 1772, 699, 1771, 738, 1646, 737],
#    'text': "They're"},
#   {'boundingBox': [1780, 699, 1922, 699, 1922, 737, 1780, 738],
#    'text': 'standing'},
#   {'boundingBox': [1930, 699, 1973, 699, 1974, 736, 1930, 737], 'text': 'up'},
#   {'boundingBox': [1982, 698, 2033, 697, 2034, 735, 1982, 736], 'text': 'for'},
#   {'boundingBox': [2042, 697, 2191, 692, 2192, 730, 2042, 735],
#    'text': "smokers'"},
#   {'boundingBox': [1642, 737, 1755, 738, 1756, 774, 1642, 775],
#    'text': 'rights.'},
#   {'boundingBox': [1763, 738, 1883, 737, 1884, 773, 1763, 774],
#    'text': 'Writing'},
#   {'boundingBox': [1891, 736, 2001, 734, 2003, 771, 1892, 773],
#    'text': 'letters'},
#   {'boundingBox': [2009, 734, 2044, 733, 2046, 770, 2010, 771], 'text': 'to'},
#   {'boundingBox': [2052, 732, 2177, 727, 2179, 767, 2053, 770],
#    'text': 'elected'},
#   {'boundingBox': [1645, 773, 1784, 774, 1785, 809, 1645, 811],
#    'text': 'officials.'},
#   {'boundingBox': [1792, 774, 1944, 772, 1945, 808, 1792, 809],
#    'text': 'Speaking'},
#   {'boundingBox': [1952, 772, 1997, 771, 1998, 808, 1953, 808], 'text': 'up'},
#   {'boundingBox': [2005, 771, 2036, 770, 2036, 808, 2006, 808], 'text': 'at'},
#   {'boundingBox': [2043, 770, 2155, 766, 2156, 808, 2044, 808],
#    'text': 'public'},
#   {'boundingBox': [1644, 810, 1800, 808, 1800, 847, 1644, 850],
#    'text': 'hearings.'},
#   {'boundingBox': [1808, 808, 1876, 808, 1876, 846, 1808, 846], 'text': 'And'},
#   {'boundingBox': [1884, 808, 2001, 808, 2002, 846, 1884, 846],
#    'text': "they're"},
#   {'boundingBox': [2009, 808, 2139, 810, 2141, 847, 2010, 846],
#    'text': 'making'},
#   {'boundingBox': [2147, 810, 2168, 810, 2169, 848, 2148, 847], 'text': 'a'},
#   {'boundingBox': [524, 943, 843, 878, 867, 1034, 546, 1069], 'text': 'your'},
#   {'boundingBox': [867, 873, 1302, 805, 1329, 945, 891, 1030],
#    'text': 'rights!'},
#   {'boundingBox': [1646, 849, 1753, 849, 1753, 885, 1645, 887],
#    'text': 'strong'},
#   {'boundingBox': [1761, 849, 1873, 848, 1873, 884, 1760, 885],
#    'text': 'impact'},
#   {'boundingBox': [1881, 847, 1913, 847, 1913, 883, 1881, 884], 'text': 'at'},
#   {'boundingBox': [1920, 847, 2015, 845, 2016, 882, 1921, 883],
#    'text': 'every'},
#   {'boundingBox': [2023, 845, 2100, 842, 2101, 880, 2024, 882],
#    'text': 'level'},
#   {'boundingBox': [2108, 842, 2135, 841, 2136, 880, 2109, 880], 'text': '-'},
#   {'boundingBox': [2160, 840, 2230, 837, 2232, 878, 2162, 879],
#    'text': 'from'},
#   {'boundingBox': [1646, 882, 1841, 883, 1842, 920, 1648, 921],
#    'text': 'Washington'},
#   {'boundingBox': [1849, 883, 1938, 882, 1940, 919, 1850, 920],
#    'text': 'right'},
#   {'boundingBox': [1946, 882, 2033, 881, 2034, 919, 1947, 919],
#    'text': 'down'},
#   {'boundingBox': [2041, 881, 2074, 881, 2075, 919, 2042, 919], 'text': 'to'},
#   {'boundingBox': [2082, 881, 2164, 879, 2165, 920, 2083, 919],
#    'text': 'local'},
#   {'boundingBox': [2172, 879, 2231, 878, 2231, 920, 2172, 920],
#    'text': 'city'},
#   {'boundingBox': [1646, 921, 1709, 922, 1710, 959, 1647, 959], 'text': 'and'},
#   {'boundingBox': [1717, 922, 1829, 922, 1829, 959, 1717, 959],
#    'text': 'county'},
#   {'boundingBox': [1836, 922, 2056, 922, 2056, 957, 1837, 959],
#    'text': 'government.'},
#   {'boundingBox': [1651, 991, 1738, 992, 1738, 1040, 1651, 1039],
#    'text': 'You'},
#   {'boundingBox': [1753, 992, 1834, 992, 1834, 1041, 1753, 1040],
#    'text': 'can'},
#   {'boundingBox': [1849, 992, 1911, 991, 1912, 1041, 1849, 1041],
#    'text': 'be'},
#   {'boundingBox': [1920, 991, 2029, 990, 2030, 1040, 1921, 1041],
#    'text': 'part'},
#   {'boundingBox': [2038, 990, 2087, 989, 2089, 1039, 2039, 1040],
#    'text': 'of'},
#   {'boundingBox': [2097, 989, 2137, 988, 2138, 1038, 2098, 1039],
#    'text': 'it'},
#   {'boundingBox': [2146, 987, 2217, 985, 2219, 1036, 2148, 1038],
#    'text': 'all!'},
#   {'boundingBox': [1724, 1056, 1793, 1056, 1792, 1097, 1724, 1098],
#    'text': '(See'},
#   {'boundingBox': [1801, 1056, 1892, 1054, 1892, 1096, 1801, 1097],
#    'text': 'other'},
#   {'boundingBox': [1900, 1054, 1969, 1054, 1969, 1097, 1900, 1096],
#    'text': 'side'},
#   {'boundingBox': [1977, 1053, 2029, 1053, 2029, 1097, 1977, 1097],
#    'text': 'for'},
#   {'boundingBox': [2038, 1053, 2167, 1051, 2167, 1101, 2038, 1098],
#    'text': 'details.)'}],
#  'full_text': "52248 7681 For years, anti-smokers have been trying to take advantage of you just because you smoke! . .. SMOKERS! They've been raising your cigarette taxes. Discriminating against you in the workplace. Forbidding you to smoke in public places - even in your own home! Get together They've been treating you like a second-class citizen. But it isn't working any more. Now smokers are fighting back. to protect They're standing up for smokers' rights. Writing letters to elected officials. Speaking up at public hearings. And they're making a your rights! strong impact at every level - from Washington right down to local city and county government. You can be part of it all! (See other side for details.)"}

# %%
question, answer
# Out:
# ('Who are the Smokers writing letters to?', 'Elected officials')

# %%
len(ocr['full_text'].split())
# Out:
# 118

# %%
val_ds.show_batch(size=10, figsize=(10, 7))
# Out:
# 2021-01-06 23:56:48 | WARNING | matplotlib.image | Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
plotlib.image | Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# OCR: ALL TRIP TVL INC NO 18598 243 SHANKS DR ROBERT E 12/2 302 E MANCHESTER BLVD 11/28/60 ST LOUIS MO 8/50 INGLEWOOD CAL WJ/MB 1400 8.50 HOTEL DUPONT PLAZA Dupont Circle, Washington 6, D. C. Acct. Forwarded from No.............................................to NO................. All Bills Due When Rendered DATE 14/28/60 30 12 - 1 2 BROUGHT FORWARD $501 14 - 876 2348 38 05 5200 ROOM 141 - 8 50 D. C. SALES TAX 261 42 126 CAFE 138 738 72 2/14 LOCAL PHONE 30 PHONE SER. CHG. LONG DISTANCE TELEGRAMS GARAGE STORAGE LAUNDRY VALET MISC. CHARGES CASH DISBURSED 150 TRANSFER TOTAL CREDITS CASH RECEIVED 53 38 ALLOWANCE TRANSFER CARRIED FORWARD PACKWOOD PRINTING CO., WASH. 1. D. C.. C. C. No.....................................K. By.............. Charge to..................... ....... Street............... Guest's Signature.............. City- State......... We hope your visit was pleasant and our services entirely satisfactory. The management will appreciate your comments. Source: https://www.industrydocuments.ucsi.edu/docs/zzin0227
# Question: What was the date of checking in at the hotel?
# Answer: 11/28/60

# %%
len(val_ds), len(train_ds), len(test_ds)
# Out:
# (5349, 39463, 5188)

# %% [markdown]
# ### Tamanhos de perguntas e respostas médias e máximas

# %%
from tqdm.notebook import tqdm
qs = []
ans = []
for i in tqdm(range(1000)):
    _, _, question, answer = val_ds[i]
    qs.append(question)
    ans.append(answer)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
np.mean([len(q.split()) for q in qs]), np.max([len(q.split()) for q in qs])
# Out:
# (8.47, 22)

# %%
np.mean([len(a.split()) for a in ans]), np.max([len(a.split()) for a in ans])
# Out:
# (2.153, 11)

# %% [markdown]
# ## Classes do Modelo

# %% [markdown]
# ### Modelo

# %%
class T5Finetuner(pl.LightningModule):

    def __init__(self, train_dataloader, val_dataloader, test_dataloader, 
                 tokenizer, params, manual_checkpoint=False, save_name='model',
                 date=None):
        super(T5Finetuner, self).__init__()

        self.params = params
        self.only_decoder = self.params['only_decoder']
        self.learning_rate = params['learning_rate']
        
        self._train_dataloader = train_dataloader
        self._val_dataloader   = val_dataloader
        self._test_dataloader  = test_dataloader

        self.tokenizer = tokenizer
        self.t5 = T5ForConditionalGeneration.from_pretrained(params['model_name'])

        # Modificado a partir da solução da Gabriela.
        # Para conversão dos patches em embeddings (384, 768)
        self.patch = nn.Conv2d(in_channels=3, out_channels=384, kernel_size=28, stride=24, padding=4)
        
        self.question_positional = nn.Embedding(20, self.t5.config.d_model)

        self.manual_checkpoint = manual_checkpoint
        self.save_name = save_name
        self.run_datetime = date if date else datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
    
    def _generate_tokens(self, embedding):
        """Do código do Diedre.

        Adaptação de código da aula 10 do semestre passado.
        Usa features para gerar frases com T5.

        A forma que faz mais sentido pra mim é usar encoder_outputs como 
        sendo as features e deixar o t5 usar embeddings de texto padrão na 
        decodificação. Não sei se está 100% correto.

        """
        max_length = self.params['seq_len']

        # Add start of sequence token
        decoded_ids = torch.full((embedding.shape[0], 1),
                                 self.t5.config.decoder_start_token_id,
                                 dtype=torch.long).to(embedding.device)

        if not self.only_decoder:
            # Passa os embeddings pelo encoder
            encoder_hidden_states = self.t5.get_encoder()(inputs_embeds=embedding)

        for step in range(max_length-1):
            if not self.only_decoder:
                # Full T5, usa os embeddings computados pelo encoder na decodificação
                logits = self.t5(decoder_input_ids=decoded_ids,
                                 encoder_outputs=encoder_hidden_states)[0]
            else:
                logits = self.t5(decoder_input_ids=decoded_ids,
                                 encoder_outputs=(embedding,))[0]
                
            next_token_logits = logits[:, -1, :]

            # Greedy decoding
            next_token_id = next_token_logits.argmax(1).unsqueeze(-1)
            
            # Check if output is end of senquence for all batches
            if torch.eq(next_token_id[:, -1], self.tokenizer.eos_token_id).all():
                break

            # Concatenate past ids with new id, keeping batch dimension
            decoded_ids = torch.cat([decoded_ids, next_token_id], dim=-1)

        return decoded_ids


    def _embeds_forward(self, img):
        """Conversão de um batch de imagens para embeddings.
        
        Args:
            img (Tensor): Batch de imagens de shape (batch, 3, 768, 576).
            
        Return:
            inputs (Tensor): Batch de embeddings de imagem de shape (batch, 385, 768).
        
        """
        features = img
        
        # Transform patches to input them in the T5 model
        features = self.patch(features)
        
        # Reshape the output to the 2D format of the tranformer.
        # Shape: (batch, 384, 768)
        inputs = features \
            .permute(0, 2, 3, 1) \
            .reshape(features.shape[0], -1, self.t5.config.d_model)
                
        return inputs
    
    
    def _embeds_question(self, question):
        """Conversão de perguntas em embeddings e adição de embedding posicional.
        
        Args: 
            question (Tensor): Batch de perguntas de shape (batch x seq_len).
            
        Return:
            question_embedding (Tensor): Batch de embeddings das perguntas de
            shape (batch x seq_len x d_model)
        
        """
        question_embedding = self.t5.shared(question)
        
        question_embedding += self.question_positional(torch.arange(question_embedding.shape[1],
                                                                    device=question.device))
        
        return question_embedding
    

    def forward(self, batch):
        """Forward pass.
        
        Converte imagens e perguntas em embeddings e as concatena.
        
        """
        images, questions, answers, encoded_questions, encoded_answers = batch

        # Shape: (batch x 384 x 768)
        image_embeddings = self._embeds_forward(images)

        # Shape: (batch x 20 x 768)
        question_embeddings = self._embeds_question(encoded_questions)
        
        # Concatenação com os embeddings da imagem
        # Shape: (batch x 404 x 768)
        embeddings = torch.cat((image_embeddings, question_embeddings), dim=1)

        if self.training:
            if self.only_decoder:
                outputs = self.t5(encoder_outputs=(embeddings,), 
                                  labels=encoded_answers,
                                  return_dict=True)
            else:
                outputs = self.t5(inputs_embeds=embeddings, 
                                  labels=encoded_answers,
                                  return_dict=True)
            
            return outputs.loss
        else:
            return self._generate_tokens(image_embeddings)

    def training_step(self, batch, batch_idx): 
        loss = self(batch)
        self.log('loss', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        pred_tokens = self(batch)
        # Tokens -> String
        decoded_pred = [self.tokenizer.decode(tokens) for tokens in pred_tokens]
        answers = batch[2]
        return {"pred": decoded_pred, "target": answers}

    def test_step(self, batch, batch_idx):
        pred_tokens = self(batch)
        # Tokens -> String
        decoded_pred = [self.tokenizer.decode(tokens) for tokens in pred_tokens]
        answers = batch[2]
        return {"pred": decoded_pred, "target": answers}

    def validation_epoch_end(self, outputs):
        # Flatten dos targets e preds para arrays
        trues = sum([list(x['target']) for x in outputs], [])
        preds = sum([list(x['pred']) for x in outputs], [])

        n = random.choice(range(len(trues)))
        print(f"\nSample Target: {trues[n]}\nPrediction: {preds[n]}\n")
        
        f1 = []
        exact = []
        for true, pred in zip(trues, preds):
            f1.append(compute_f1(a_gold=true, a_pred=pred))
            exact.append(compute_exact(a_gold=true, a_pred=pred))
        f1 = np.mean(f1)
        exact = np.mean(exact)

        self.log("val_f1", f1, prog_bar=True)
        self.log("val_exact", exact, prog_bar=True)
        
        if self.manual_checkpoint and self.global_step != 0:
            step, epoch, save_name = self.global_step, self.current_epoch, self.save_name
            ckpt_path = Path(f"checkpoints/{save_name}/{self.run_datetime}")
            ckpt_name = f'{save_name}-epoch-{epoch}-step-{str(step).zfill(6)}-val_f1-{f1:.5f}-EM-{exact:.5f}.pt'
            
            ckpt_path.mkdir(parents=True, exist_ok=True)
            torch.save(self.state_dict(), ckpt_path / ckpt_name)

    def test_epoch_end(self, outputs):
        # Flatten dos targets e preds para arrays
        trues = sum([list(x['target']) for x in outputs], [])
        preds = sum([list(x['pred']) for x in outputs], [])

        n = random.choice(range(len(trues)))
        print(f"\nSample Target: {trues[n]}\nPrediction: {preds[n]}\n")

        f1 = []
        exact = []
        for true, pred in zip(trues, preds):
            f1.append(compute_f1(a_gold=true, a_pred=pred))
            exact.append(compute_exact(a_gold=true, a_pred=pred))
        f1 = np.mean(f1)
        exact = np.mean(exact)

        self.log("test_f1", f1, prog_bar=True)
        self.log("test_exact", exact, prog_bar=True)

    def configure_optimizers(self):
        if self.params['optimizer'] == 'Adafactor':
            optimizer = Adafactor(
                    [p for p in self.parameters() if p.requires_grad],
                    scale_parameter=False, relative_step=False, 
                    lr=self.learning_rate)
        elif self.params['optimizer'] == 'Adam':
            optimizer = torch.optim.Adam(
                [p for p in self.parameters() if p.requires_grad],
                lr=self.learning_rate, eps=1e-08)
        return optimizer

    def train_dataloader(self):
        return self._train_dataloader

    def val_dataloader(self):
        return self._val_dataloader

    def test_dataloader(self):
        return self._test_dataloader

# %% [markdown]
# ### Collate

# %%
def collate_fn(batch, params={'seq_len_questions': 20,
                              'seq_len': 128,
                              'task': 'squad'}):
    """ Tokenização do batch.
    
    """    
    imgs = torch.as_tensor(torch.stack([sample[0] for sample in batch]))
    ocrs = [sample[1] for sample in batch]
    questions = [sample[2] for sample in batch]
    answers = [sample[3] for sample in batch]
    
    # Dict com 'input_ids' e 'attention_mask'
    # seq_len_questions != seq_len do texto
    encoded_questions = tokenizer.batch_encode_plus(questions, 
                                          # padding='longest',
                                          padding='max_length',
                                          truncation=True,
                                          max_length=params['seq_len_questions'],
                                          return_tensors='pt')['input_ids']
    
    encoded_answers = tokenizer.batch_encode_plus(answers, 
                                                  # padding='longest',
                                                  padding='max_length',
                                                  truncation=True,
                                                  max_length=params['seq_len'],
                                                  return_tensors='pt')['input_ids']
    
    return imgs, questions, answers, encoded_questions, encoded_answers

# %% [markdown]
# ## Parâmetros e Dataloaders

# %%
params = {
    'model_name': model_name, # definido lá no topo do código
    'only_decoder': False,
    'optimizer': 'Adafactor',
    'batch_size': 2,
    'batch_size_eval': 2,
    'num_workers': 4,
    'seq_len': 20,            # seq len do texto gerado
    'seq_len_questions': 20,  # seq len das perguntas
    'learning_rate': 5e-4,
    'max_epochs': 30,
    'patience': 10,
    'monitor_variable': 'val_f1', # Critério do early stopping,
}

_collate = partial(collate_fn, params=params)

train_loader = DataLoader(train_ds,
                          batch_size=params['batch_size'],
                          num_workers=params['num_workers'], 
                          collate_fn=_collate)

val_loader = DataLoader(val_ds,
                        batch_size=params['batch_size_eval'],
                        num_workers=params['num_workers'],
                        collate_fn=_collate)

test_loader = DataLoader(test_ds,
                         batch_size=params['batch_size_eval'],
                         num_workers=params['num_workers'],
                         collate_fn=_collate)

# %% [markdown]
# ## Teste preliminar
#
# Para debug.

# %%
model = T5Finetuner(train_dataloader=train_loader,
                    val_dataloader=val_loader,
                    test_dataloader=test_loader,
                    tokenizer=tokenizer,
                    params=params)

trainer = pl.Trainer(gpus=1, 
                     checkpoint_callback=False,  # Disable checkpoint saving.
                     fast_dev_run=True)

trainer.fit(model)
trainer.test(model)
del model, trainer  # Para não ter estouro de mémoria da GPU
# Out:
# GPU available: True, used: True
# 2021-01-06 23:35:08 | INFO | lightning | GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# 2021-01-06 23:35:08 | INFO | lightning | TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-06 23:35:08 | INFO | lightning | LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Running in fast_dev_run mode: will run a full train, val and test loop using a single batch
# 2021-01-06 23:35:08 | INFO | lightning | Running in fast_dev_run mode: will run a full train, val and test loop using a single batch
#
#   | Name                | Type                       | Params
# -------------------------------------------------------------------
# 0 | t5                  | T5ForConditionalGeneration | 222 M
# 1 | patch               | Conv2d                     | 903 K
# 2 | question_positional | Embedding                  | 15 K
# 2021-01-06 23:35:12 | INFO | lightning |
#   | Name                | Type                       | Params
# -------------------------------------------------------------------
# 0 | t5                  | T5ForConditionalGeneration | 222 M
# 1 | patch               | Conv2d                     | 903 K
# 2 | question_positional | Embedding                  | 15 K
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Sample Target: Vanderbilt university
# Prediction:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# Sample Target: No answer.
# Prediction:
#
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_exact': 0.0, 'test_f1': 0.0}
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Treino rápido para ver se a loss está reduzindo

# %%
model = T5Finetuner(train_dataloader=train_loader,
                    val_dataloader=val_loader,
                    test_dataloader=None,
                    tokenizer=tokenizer,
                    params=params)

trainer = pl.Trainer(gpus=1, 
                     max_epochs=50,
                     check_val_every_n_epoch=10,
                     checkpoint_callback=False,  # Disable checkpoint saving.
                     overfit_batches=2)
trainer.fit(model)
del model, trainer  # Para não ter estouro de mémoria da GPU
# Out:
# GPU available: True, used: True
# 2021-01-06 23:37:33 | INFO | lightning | GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# 2021-01-06 23:37:33 | INFO | lightning | TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-06 23:37:33 | INFO | lightning | LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                | Type                       | Params
# -------------------------------------------------------------------
# 0 | t5                  | T5ForConditionalGeneration | 222 M
# 1 | patch               | Conv2d                     | 903 K
# 2 | question_positional | Embedding                  | 15 K
# 2021-01-06 23:37:33 | INFO | lightning |
#   | Name                | Type                       | Params
# -------------------------------------------------------------------
# 0 | t5                  | T5ForConditionalGeneration | 222 M
# 1 | patch               | Conv2d                     | 903 K
# 2 | question_positional | Embedding                  | 15 K
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# Sample Target: 7 - 1 - 99
# Prediction:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Sample Target: 91301
# Prediction:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Sample Target: 91301
# Prediction:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Sample Target: 7 - 1 - 99
# Prediction:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Sample Target: USA Petroleum
# Prediction:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# Sample Target: 91301
# Prediction:

# %% [markdown]
# # Treino

# %%
task_model_name = "docvqa-from-ocr"

# Checkpoint the best model.
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    prefix=task_model_name,
    filepath="logs/{epoch}-{val_f1:.2f}-{val_exact:.2f}", 
    monitor="val_f1", 
    mode="max",
)

callbacks = [pl.callbacks.EarlyStopping(monitor=params['monitor_variable'], 
                                        patience=params["patience"], 
                                        mode='max')]

run_time = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')


neptune_logger = NeptuneLogger(
    api_key=neptune_params['api_key'],
    project_name=neptune_params['project_name'],
    params=params,
    tags=['TRAIN', 
          f"task: {task_model_name}", 
          'with-weights',
          'patch',
          '768x576', 
          'normed-img',
          run_time],
)


trainer = pl.Trainer(gpus=1,
                     precision=32,
                     log_gpu_memory=True,
                     max_epochs=params['max_epochs'],
                     # check_val_every_n_epoch=1,
                     progress_bar_refresh_rate=16,
                     accumulate_grad_batches=8,
                     limit_val_batches=0.2,
                     val_check_interval=10000,
                     profiler=True,
                     logger=neptune_logger,
                     # callbacks=callbacks,
                     checkpoint_callback=checkpoint_callback)

model = T5Finetuner(train_dataloader=train_loader,
                    val_dataloader=val_loader,
                    test_dataloader=test_loader,
                    tokenizer=tokenizer,
                    params=params,
                    manual_checkpoint=True,     # Salva checkpoints a cada validação
                    save_name=task_model_name,  # Nome do modelo salvo
                    date=run_time)

if task_model_name == 'docvqa-from-ocr':
    weights = 'checkpoints/squad-v2-ocr/2020-12-30_11-55-47/squad-v2-ocr-epoch-8-step-069503-val_f1-0.20024-EM-0.00000.pt'
elif task_model_name == 'docvqa-from-vqa':
    weights = 'checkpoints/squad-v2-vqa/2021-01-04_20-56-58/squad-v2-vqa-epoch-2-step-023625-val_f1-0.01677-EM-0.00000.pt'
if weights:
    print('Loading pretrained weights...')
    model.load_state_dict(torch.load(weights))

trainer.fit(model)
# Out:
# WARNING: There is a new version of neptune-client 0.4.130 (installed: 0.4.129).
# https://ui.neptune.ai/lupozz/ia376-doc-vqa/e/DOCVQA-3
# NeptuneLogger will work in online mode
# 2021-01-07 01:15:23 | INFO | lightning | NeptuneLogger will work in online mode
# GPU available: True, used: True
# 2021-01-07 01:15:23 | INFO | lightning | GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# 2021-01-07 01:15:23 | INFO | lightning | TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-01-07 01:15:23 | INFO | lightning | LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loading pretrained weights...
#   | Name                | Type                       | Params
# -------------------------------------------------------------------
# 0 | t5                  | T5ForConditionalGeneration | 222 M
# 1 | patch               | Conv2d                     | 903 K
# 2 | question_positional | Embedding                  | 15 K
# 2021-01-07 01:15:31 | INFO | lightning |
#   | Name                | Type                       | Params
# -------------------------------------------------------------------
# 0 | t5                  | T5ForConditionalGeneration | 222 M
# 1 | patch               | Conv2d                     | 903 K
# 2 | question_positional | Embedding                  | 15 K
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# Sample Target: $123,110
# Prediction: Sichuan consists of two geographically very distinct parts. The eastern part is mostly within
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# 2021-01-07 01:17:21 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:17:19.728Z, x=49.0, numericValue=0.0, textValue=null, imag', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 49.0) Skipping 3 values.
# 2021-01-07 01:22:36 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:22:36.089Z, x=199.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 199.0) Skipping 3 values.
# 2021-01-07 01:22:41 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:22:37.177Z, x=199.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 199.0) Skipping 3 values.
# 2021-01-07 01:24:21 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:24:21.271Z, x=249.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 249.0) Skipping 3 values.
# 2021-01-07 01:24:26 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:24:22.024Z, x=249.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 249.0) Skipping 3 values.
# 2021-01-07 01:26:06 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:26:06.185Z, x=299.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 299.0) Skipping 3 values.
# 2021-01-07 01:26:11 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:26:06.622Z, x=299.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 299.0) Skipping 3 values.
# 2021-01-07 01:27:51 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:27:51.070Z, x=349.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 349.0) Skipping 3 values.
# 2021-01-07 01:29:36 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:29:35.534Z, x=399.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 399.0) Skipping 3 values.
# 2021-01-07 01:31:21 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:31:19.928Z, x=449.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 449.0) Skipping 3 values.
# 2021-01-07 01:33:06 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:33:04.433Z, x=499.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 499.0) Skipping 3 values.
# 2021-01-07 01:34:51 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:34:48.973Z, x=549.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 549.0) Skipping 3 values.
# 2021-01-07 01:36:36 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:36:33.639Z, x=599.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 599.0) Skipping 3 values.
# 2021-01-07 01:38:17 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:38:16.399Z, x=649.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 649.0) Skipping 3 values.
# 2021-01-07 01:38:21 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:38:18.139Z, x=649.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 649.0) Skipping 3 values.
# 2021-01-07 01:40:01 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:40:01.402Z, x=699.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 699.0) Skipping 3 values.
# 2021-01-07 01:40:06 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:40:02.489Z, x=699.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 699.0) Skipping 3 values.
# 2021-01-07 01:41:46 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:41:46.297Z, x=749.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 749.0) Skipping 3 values.
# 2021-01-07 01:41:51 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:41:47.051Z, x=749.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 749.0) Skipping 3 values.
# 2021-01-07 01:43:31 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:43:31.249Z, x=799.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 799.0) Skipping 3 values.
# 2021-01-07 01:43:36 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:43:31.679Z, x=799.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 799.0) Skipping 3 values.
# 2021-01-07 01:45:16 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:45:16.010Z, x=849.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 849.0) Skipping 3 values.
# 2021-01-07 01:47:01 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:47:00.678Z, x=899.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 899.0) Skipping 3 values.
# 2021-01-07 01:48:46 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:48:45.213Z, x=949.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 949.0) Skipping 3 values.
# 2021-01-07 01:50:31 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:50:29.742Z, x=999.0, numericValue=0.0, textValue=null, ima', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 999.0) Skipping 3 values.
# 2021-01-07 01:52:16 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:52:14.169Z, x=1049.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1049.0) Skipping 3 values.
# 2021-01-07 01:54:01 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:53:58.527Z, x=1099.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1099.0) Skipping 3 values.
# 2021-01-07 01:55:41 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:55:41.145Z, x=1149.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1149.0) Skipping 3 values.
# 2021-01-07 01:55:46 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:55:42.876Z, x=1149.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1149.0) Skipping 3 values.
# 2021-01-07 01:57:26 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:57:26.322Z, x=1199.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1199.0) Skipping 3 values.
# 2021-01-07 01:57:31 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:57:27.409Z, x=1199.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1199.0) Skipping 3 values.
# 2021-01-07 01:59:11 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:59:11.434Z, x=1249.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1249.0) Skipping 3 values.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# 2021-01-07 01:59:16 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T01:59:11.869Z, x=1249.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1249.0) Skipping 3 values.
# Sample Target: RJReynolds Tobacco Company
# Prediction: a st. louis
# 2021-01-07 02:01:51 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T02:01:49.761Z, x=1249.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1249.0) Skipping 2 values.
# 2021-01-07 02:03:36 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-07T02:03:35.847Z, x=1299.0, numericValue=0.0, textValue=null, im', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 1299.0) Skipping 3 values.
# 2021-01-07 02:05:21 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# ...
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:32:09.214Z, x=73649.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73649.0) Skipping 3 values.
# 2021-01-08 21:33:56 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:33:53.948Z, x=73699.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73699.0) Skipping 3 values.
# 2021-01-08 21:35:41 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:35:39.372Z, x=73749.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73749.0) Skipping 3 values.
# 2021-01-08 21:37:26 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:37:24.928Z, x=73799.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73799.0) Skipping 3 values.
# 2021-01-08 21:39:11 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:39:10.222Z, x=73849.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73849.0) Skipping 3 values.
# 2021-01-08 21:40:56 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:40:55.753Z, x=73899.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73899.0) Skipping 3 values.
# 2021-01-08 21:42:41 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:42:40.791Z, x=73949.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73949.0) Skipping 3 values.
# 2021-01-08 21:42:46 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:42:41.234Z, x=73949.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73949.0) Skipping 3 values.
# 2021-01-08 21:44:26 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:44:25.810Z, x=73999.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73999.0) Skipping 3 values.
# 2021-01-08 21:44:31 | ERROR | neptune.internal.channels.channels_values_sender | Failed to send channel value.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/channels/channels_values_sender.py", line 156, in _send_values
#     self._experiment._send_channels_values(channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/experiments.py", line 1167, in _send_channels_values
#     self._backend.send_channels_values(self, channels_with_values)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/utils.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/neptune/internal/backends/hosted_neptune_backend.py", line 571, in send_channels_values
#     raise ChannelsValuesSendBatchError(experiment.id, batch_errors)
# neptune.api_exceptions.ChannelsValuesSendBatchError: Received batch errors sending channels' values to experiment DOCVQA-3. Cause: Error(code=400, message='X-coordinates must be strictly increasing for channel: f6f50548-0fed-46bf-81c1-7c8d423d7ce0. Invalid point: InputChannelValue(timestamp=2021-01-08T21:44:26.618Z, x=73999.0, numericValue=29.0, textValue=null, ', type=None) (metricId: 'f6f50548-0fed-46bf-81c1-7c8d423d7ce0', x: 73999.0) Skipping 3 values.
# Profiler Report
#
# Action              	|  Mean duration (s)	|  Total time (s)
# -----------------------------------------------------------------
# on_fit_start        	|  5.604e-05      	|  5.604e-05
# on_validation_start 	|  0.024702       	|  0.76576
# on_validation_epoch_start	|  3.2522e-05     	|  0.0010082
# on_validation_batch_start	|  3.1872e-05     	|  0.5116
# validation_step_end 	|  2.919e-05      	|  0.46856
# on_validation_batch_end	|  0.00020996     	|  3.3703
# on_validation_epoch_end	|  9.3184e-05     	|  0.0028887
# on_validation_end   	|  0.36055        	|  11.177
# on_train_start      	|  0.025394       	|  0.025394
# on_epoch_start      	|  0.0032195      	|  0.096584
# on_train_epoch_start	|  2.0186e-05     	|  0.00060559
# get_train_batch     	|  0.0033768      	|  1998.9
# on_batch_start      	|  4.2925e-05     	|  25.41
# on_train_batch_start	|  2.0771e-05     	|  12.296
# training_step_end   	|  3.1086e-05     	|  18.401
# model_forward       	|  0.099076       	|  5.8649e+04
# model_backward      	|  0.13856        	|  8.2022e+04
# on_batch_end        	|  3.7689e-05     	|  22.31
# on_train_batch_end  	|  0.00024635     	|  145.83
# on_after_backward   	|  3.4892e-05     	|  2.5824
# optimizer_step      	|  0.33203        	|  2.4573e+04
# on_epoch_end        	|  2.1782e-05     	|  0.00065346
# on_train_epoch_end  	|  2.3055e-05     	|  0.00069164
# on_train_end        	|  0.0018724      	|  0.0018724
#
# 2021-01-08 21:44:53 | INFO | lightning |
#
# Profiler Report
#
# Action              	|  Mean duration (s)	|  Total time (s)
# -----------------------------------------------------------------
# on_fit_start        	|  5.604e-05      	|  5.604e-05
# on_validation_start 	|  0.024702       	|  0.76576
# on_validation_epoch_start	|  3.2522e-05     	|  0.0010082
# on_validation_batch_start	|  3.1872e-05     	|  0.5116
# validation_step_end 	|  2.919e-05      	|  0.46856
# on_validation_batch_end	|  0.00020996     	|  3.3703
# on_validation_epoch_end	|  9.3184e-05     	|  0.0028887
# on_validation_end   	|  0.36055        	|  11.177
# on_train_start      	|  0.025394       	|  0.025394
# on_epoch_start      	|  0.0032195      	|  0.096584
# on_train_epoch_start	|  2.0186e-05     	|  0.00060559
# get_train_batch     	|  0.0033768      	|  1998.9
# on_batch_start      	|  4.2925e-05     	|  25.41
# on_train_batch_start	|  2.0771e-05     	|  12.296
# training_step_end   	|  3.1086e-05     	|  18.401
# model_forward       	|  0.099076       	|  5.8649e+04
# model_backward      	|  0.13856        	|  8.2022e+04
# on_batch_end        	|  3.7689e-05     	|  22.31
# on_train_batch_end  	|  0.00024635     	|  145.83
# on_after_backward   	|  3.4892e-05     	|  2.5824
# optimizer_step      	|  0.33203        	|  2.4573e+04
# on_epoch_end        	|  2.1782e-05     	|  0.00065346
# on_train_epoch_end  	|  2.3055e-05     	|  0.00069164
# on_train_end        	|  0.0018724      	|  0.0018724
# 1

# %%
# Guardando aqui no fim do código, pode ser útil
import gc
# del model, trainer

gc.collect()
torch.cuda.memory_allocated() / 1024
# Out:
# 882514.0

# %% [markdown]
# # Conclusões

# %% [markdown]
# - O pré-treino de OCR não colaborou com bons resultados de treino do DocVQA. De todo modo, creio que o pré-treino não estava bom para começar.
